# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import zscore
import os

# %%
# Read the raw dataset
df = pd.read_csv('C:/Users/hlina/solar-challenge-week1/data/benin-malanville.csv')

# %%
# Summary statistics
print("Summary statistics:")
print(df.describe())
# Out:
# Summary statistics:
#                  GHI            DNI            DHI           ModA  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      240.559452     167.187516     115.358961     236.589496
# std       331.131327     261.710501     158.691074     326.894859
# min       -12.900000      -7.800000     -12.600000       0.000000
# 25%        -2.000000      -0.500000      -2.100000       0.000000
# 50%         1.800000      -0.100000       1.600000       4.500000
# 75%       483.400000     314.200000     216.300000     463.700000
# max      1413.000000     952.300000     759.200000    1342.300000
#
#                 ModB           Tamb             RH             WS  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      228.883576      28.179683      54.487969       2.121113
# std       316.536515       5.924297      28.073069       1.603466
# min         0.000000      11.000000       2.100000       0.000000
# 25%         0.000000      24.200000      28.800000       1.000000
# 50%         4.300000      28.000000      55.100000       1.900000
# 75%       447.900000      32.300000      80.100000       3.100000
# max      1342.300000      43.800000     100.000000      19.500000
#
#               WSgust        WSstdev             WD        WDstdev  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean        2.809195       0.473390     153.435172       8.582407
# std         2.029120       0.273395     102.332842       6.385864
# min         0.000000       0.000000       0.000000       0.000000
# 25%         1.300000       0.400000      59.000000       3.700000
# 50%         2.600000       0.500000     181.000000       8.600000
# 75%         4.100000       0.600000     235.100000      12.300000
# max        26.600000       4.200000     360.000000      99.400000
#
#                   BP       Cleaning  Precipitation          TModA  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      994.197199       0.000923       0.001905      35.246026
# std         2.474993       0.030363       0.037115      14.807258
# min       985.000000       0.000000       0.000000       9.000000
# 25%       993.000000       0.000000       0.000000      24.200000
# 50%       994.000000       0.000000       0.000000      30.000000
# 75%       996.000000       0.000000       0.000000      46.900000
# max      1003.000000       1.000000       2.500000      81.000000
#
#                TModB  Comments
# count  525600.000000       0.0
# mean       32.471736       NaN
# std        12.348743       NaN
# min         8.100000       NaN
# 25%        23.600000       NaN
# 50%        28.900000       NaN
# 75%        41.500000       NaN
# max        72.500000       NaN

# %%
# Missing values count
missing_counts = df.isna().sum()
print("\nMissing values count:")
print(missing_counts)
# Out:
# Missing values count:
# Timestamp             0
# GHI                   0
# DNI                   0
# DHI                   0
# ModA                  0
# ModB                  0
# Tamb                  0
# RH                    0
# WS                    0
# WSgust                0
# WSstdev               0
# WD                    0
# WDstdev               0
# BP                    0
# Cleaning              0
# Precipitation         0
# TModA                 0
# TModB                 0
# Comments         525600
# dtype: int64

# %%
# Columns with more than 5% missing values
total_rows = len(df)
missing_percent = (missing_counts / total_rows) * 100
cols_over_5pct = missing_percent[missing_percent > 5]
print("\nColumns with more than 5% missing values:")
print(cols_over_5pct)
# Out:
# Columns with more than 5% missing values:
# Comments    100.0
# dtype: float64

# %%
# Key columns for outlier and missing value handling
key_cols = ['GHI', 'DNI', 'DHI', 'ModA', 'ModB', 'WS', 'WSgust']

# %%
# Drop rows with NaN temporarily to compute z-scores
df_z = df[key_cols].dropna()

# Compute Z-scores
z_scores = np.abs(zscore(df_z))
mask = (z_scores < 3).all(axis=1)

# %%
# Create cleaned DataFrame by removing outliers
df_clean = df.loc[df_z.index[mask]].copy()

# %%
# Fill missing values in key columns with the median
for col in key_cols:
    if col in df_clean.columns:
        median_value = df_clean[col].median()
        df_clean[col] = df_clean[col].fillna(median_value)

# %%
# Ensure the output directory exists
os.makedirs("../data", exist_ok=True)

# %%
# Export cleaned DataFrame
df_clean.to_csv("../data/togo_clean.csv", index=False)
print("File saved to ../data/benin_clean.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Export cleaned DataFrame
# ----> 2 df_clean.to_csv("../data/togo_clean.csv", index=False)
#       3 print("File saved to ../data/benin_clean.csv")
#
# NameError: name 'df_clean' is not defined

# %%
# Ensure Timestamp column is datetime
df_clean['Timestamp'] = pd.to_datetime(df_clean['Timestamp'], errors='coerce')
df_clean = df_clean.dropna(subset=['Timestamp'])  # drop rows with invalid dates

# %%
# Time-based features
df_clean['Month'] = df_clean['Timestamp'].dt.month
df_clean['Hour'] = df_clean['Timestamp'].dt.hour

# %%
# Plot GHI, DNI, DHI, Tamb over time
plt.figure(figsize=(14, 6))
for col in ['GHI', 'DNI', 'DHI', 'Tamb']:
    plt.plot(df_clean['Timestamp'], df_clean[col], label=col, alpha=0.7)

plt.legend(loc='upper right')  # specify location manually
plt.title('GHI, DNI, DHI, Tamb over Time')
plt.xlabel('Timestamp')
plt.ylabel('Value')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
corr_cols = ['GHI', 'DNI', 'DHI', 'TModA', 'TModB']
corr_matrix = df_clean[corr_cols].corr()

plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
# WS vs GHI
sns.scatterplot(data=df_clean, x='WS', y='GHI')
plt.title('Wind Speed vs GHI')
plt.show()

# %%
# WSgust vs GHI
sns.scatterplot(data=df_clean, x='WSgust', y='GHI')
plt.title('Wind Gust vs GHI')
plt.show()

# %%
# WD vs GHI
sns.scatterplot(data=df_clean, x='WD', y='GHI')
plt.title('Wind Direction vs GHI')
plt.show()

# %%
# RH vs Tamb
sns.scatterplot(data=df_clean, x='RH', y='Tamb')
plt.title('Relative Humidity vs Temperature')
plt.show()

# %%
# RH vs GHI
sns.scatterplot(data=df_clean, x='RH', y='GHI')
plt.title('Relative Humidity vs GHI')
plt.show()

# %%
# Convert WD from degrees to radians
wd_rad = np.radians(df_clean['WD'])

# Create wind rose-style polar plot
plt.figure(figsize=(8, 8))
ax = plt.subplot(111, polar=True)
ax.set_theta_zero_location("N")  # North at top
ax.set_theta_direction(-1)  # Clockwise

# %%
# Convert WD (wind direction in degrees) to radians
wd_rad = np.radians(df_clean['WD'])

# Create a polar plot
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'}, figsize=(8, 6))

# Plot wind speed vs. wind direction
ax.bar(wd_rad, df_clean['WS'], width=np.radians(10), bottom=0, alpha=0.5)

# Customize the plot
ax.set_theta_zero_location('N')  # Set 0 degrees to North
ax.set_theta_direction(-1)       # Clockwise direction
ax.set_title('Wind Rose: Wind Speed vs. Wind Direction')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 8
#       5 fig, ax = plt.subplots(subplot_kw={'projection': 'polar'}, figsize=(8, 6))
#       7 # Plot wind speed vs. wind direction
# ----> 8 ax.bar(wd_rad, df_clean['WS'], width=np.radians(10), bottom=0, alpha=0.5)
#      10 # Customize the plot
#      11 ax.set_theta_zero_location('N')  # Set 0 degrees to North
#
# File c:\Users\hlina\solar-challenge-week1\venv\lib\site-packages\matplotlib\__init__.py:1521, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1518 @functools.wraps(func)
#    1519 def inner(ax, *args, data=None, **kwargs):
#    1520     if data is None:
# -> 1521         return func(
#    1522             ax,
#    1523             *map(cbook.sanitize_sequence, args),
#    1524             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1526     bound = new_sig.bind(ax, *args, **kwargs)
#    1527     auto_label = (bound.arguments.get(label_namer)
#    1528                   or bound.kwargs.get(label_namer))
#
# File c:\Users\hlina\solar-challenge-week1\venv\lib\site-packages\matplotlib\axes\_axes.py:2660, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2658     else:  # horizontal
#    2659         r.sticky_edges.x.append(l)
# -> 2660     self.add_patch(r)
#    2661     patches.append(r)
#    2663 if xerr is not None or yerr is not None:
#
# File c:\Users\hlina\solar-challenge-week1\venv\lib\site-packages\matplotlib\axes\_base.py:2482, in _AxesBase.add_patch(self, p)
#    2480 if p.get_clip_path() is None:
#    2481     p.set_clip_path(self.patch)
# -> 2482 self._update_patch_limits(p)
#    2483 self._children.append(p)
#    2484 p._remove_method = self._children.remove
#
# File c:\Users\hlina\solar-challenge-week1\venv\lib\site-packages\matplotlib\axes\_base.py:2524, in _AxesBase._update_patch_limits(self, patch)
#    2522         updatey = False
#    2523 trf_to_data = patch_trf - self.transData
# -> 2524 xys = trf_to_data.transform(vertices)
#    2525 self.update_datalim(xys, updatex=updatex, updatey=updatey)
#
# File c:\Users\hlina\solar-challenge-week1\venv\lib\site-packages\matplotlib\transforms.py:1495, in Transform.transform(self, values)
#    1492 values = values.reshape((-1, self.input_dims))
#    1494 # Transform the values
# -> 1495 res = self.transform_affine(self.transform_non_affine(values))
#    1497 # Convert the result back to the shape of the input values.
#    1498 if ndim == 0:
#
# File c:\Users\hlina\solar-challenge-week1\venv\lib\site-packages\matplotlib\transforms.py:2410, in CompositeGenericTransform.transform_affine(self, values)
#    2408 def transform_affine(self, values):
#    2409     # docstring inherited
# -> 2410     return self.get_affine().transform(values)
#
# File c:\Users\hlina\solar-challenge-week1\venv\lib\site-packages\matplotlib\transforms.py:2436, in CompositeGenericTransform.get_affine(self)
#    2434     return self._b.get_affine()
#    2435 else:
# -> 2436     return Affine2D(np.dot(self._b.get_affine().get_matrix(),
#    2437                            self._a.get_affine().get_matrix()))
#
# KeyboardInterrupt:

# %%
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
sns.histplot(df_clean['GHI'], bins=30, kde=True)
plt.title('Distribution of GHI')

plt.subplot(1, 2, 2)
sns.histplot(df_clean['WS'], bins=30, kde=True, color='orange')
plt.title('Distribution of Wind Speed')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
sns.scatterplot(x='RH', y='Tamb', data=df_clean)
plt.title('Relative Humidity vs Temperature (Tamb)')

plt.subplot(1, 2, 2)
sns.scatterplot(x='RH', y='GHI', data=df_clean, color='green')
plt.title('Relative Humidity vs Solar Radiation (GHI)')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
bubble_size = df_clean['RH'] * 2  # scale bubble size
sns.scatterplot(x='GHI', y='Tamb', size=bubble_size, data=df_clean, alpha=0.6, legend=False)

plt.title('Bubble Chart: GHI vs Tamb (Bubble Size = RH)')
plt.xlabel('GHI')
plt.ylabel('Tamb')
plt.tight_layout()
plt.show()
